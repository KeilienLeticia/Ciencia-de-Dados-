# %% [markdown]
# # Bibliotecas

# %%
"""
create table Produtos(
    ID INT,
    Nome NVARCHAR(255),
    Price money,
    Id_Category INT
)
"""

# %%
#!pip install pyodbc 

import pandas as pd
import pyodbc 

server = 'LETICIA' # Substitua pelo nome do servidor SQL Server
database = 'Python'  # Substitua pelo nome do banco de dados
conexaoDB = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                      f'SERVER={server};'
                      f'DATABASE={database};'#database = 'Python' conectar o banco python
                      'Trusted_Connection=yes;') # confirma a conexão

cursor = conexaoDB.cursor()   # criando cursor de comando

# %% [markdown]
# #### Conexão com senha

# %%
"""
server = 'EDMILSON\MSSQL' # Substitua pelo nome do servidor SQL Server
database = 'Produtos'  # Substitua pelo nome do banco de dados
conexaoDB = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                      f'SERVER={server};'
                      f'DATABASE={database};'
                      f'usuario= edmilson;'
                      f'senha=1234teste;'                      
                      'Trusted_Connection=yes;')

cursor = conexaoDB.cursor()   # criando cursor de comando
"""

# %%
dados = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Ordens.xlsx")
#display(dados)
dados.head(5)
#display(dados)
# Out:
#    id          created_at  customer_id           pagamento
# 0   0 2019-08-28 03:36:31           91            entregue
# 1   1 2019-08-16 20:21:30            7            entregue
# 2   2 2019-07-11 11:00:06           26  pagamento_pendente
# 3   3 2019-08-27 21:04:41           92  pagamento_pendente
# 4   4 2019-11-03 19:58:37           63    entrega_pendente

# %%
dados.columns
# Out:
# Index(['id', 'created_at', 'customer_id', 'pagamento'], dtype='object')

# %%
# Supondo que os nomes corretos das colunas no DataFrame sejam diferentes
dados.rename(columns={'Name': 'Nome'}, inplace=True)
# Agora, execute o código de inserção novamente

# %%
dados = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Ordens.xlsx")
#display(dados)
dados.head(5)
#display(dados)
# Out:
#    id          created_at  customer_id           pagamento
# 0   0 2019-08-28 03:36:31           91            entregue
# 1   1 2019-08-16 20:21:30            7            entregue
# 2   2 2019-07-11 11:00:06           26  pagamento_pendente
# 3   3 2019-08-27 21:04:41           92  pagamento_pendente
# 4   4 2019-11-03 19:58:37           63    entrega_pendente

# %%
str(dados.columns).replace("'","")
# Out:
# 'Index([id, created_at, customer_id, pagamento], dtype=object)'

# %%
# Comprehensive column cleaning
import pandas as pd
dados.columns = dados.columns.str.replace("'", "").str.strip().str.replace(" ", "_")

# %%
dados = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Produto.xlsx")
#display(dados)
dados.head(5)

# %%
#Conversão de dados
dados['id'] = dados.id.astype(d)  ##conversao de dados para string nvarchar

# %%
dados = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Produto.xlsx")
#display(dados)
dados.head(5)

# %%
dados.rename(columns={'Name': 'Nome'}, inplace=True)
dados.head

# %%
dados = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Produto.xlsx")
#display(dados)
dados.head(5)

# %% [markdown]
# # Inserindo DataFrame no Banco

# %%
dados.head(5)

# %%
for index, linha in dados.iterrows():
    
    cursor.execute("Insert into [Ordens](id,created_at,customer_id,pagamento)values(?,?,?,?)",linha.id,linha.created_at,linha.customer_id,linha.pagamento) 
     # inserir colunas e quantas colunas tiver passar quantidade de ??
cursor.commit()   # validar dados no SQL Server
cursor.close()    #Fechar Cursor
conexaoDB.close() #Fechar Conexao

# %%
for index, linha in dados.iterrows():
    print ( index, linha )
# Out:
# 0 id                               0
# created_at     2019-08-28 03:36:31
# customer_id                     91
# pagamento                 entregue
# Name: 0, dtype: object
# 1 id                               1
# created_at     2019-08-16 20:21:30
# customer_id                      7
# pagamento                 entregue
# Name: 1, dtype: object
# 2 id                               2
# created_at     2019-07-11 11:00:06
# customer_id                     26
# pagamento       pagamento_pendente
# Name: 2, dtype: object
# 3 id                               3
# created_at     2019-08-27 21:04:41
# customer_id                     92
# pagamento       pagamento_pendente
# Name: 3, dtype: object
# 4 id                               4
# created_at     2019-11-03 19:58:37
# customer_id                     63
# pagamento         entrega_pendente
# Name: 4, dtype: object
# 5 id                               5
# created_at     2019-04-04 07:31:10
# customer_id                      3
# ...

# %%
#cursor.execute('delete  from [dbo].[Dim_Produto]')   #executa tarefa de  apagar dados
#cursor.commit()
