# %%
"""
pip install pandas
pip install --upgrade pandas
"""

# %%
import pandas as pd

# %%
#demilitador e virgula
#pd.read_csv --- armazenar e importar para fazer a leitura
# read - ler / head - 
#delimiter - delemitador -  delemiter ' qual delemitador' tem passar o parametro
df = pd.read_csv(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_csv\Clientes.csv",delimiter=',')
df.head()
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %%
# Filtrar 1 item especifico de uma coluna
#loc e localizar um coluna
#nome = df.loc[df['last_name'] == 'Jesus']
nome = df.loc[df['last_name'] == 'Jesus']


#df = pd.DataFrame({"frutas": ["banana", "laranja", "pera", "uva", "banana", "pera"], "codigo": ["um", "dois", "mxrf11", "quatro", "cinco", "seis"]})

# %%
estado = df.loc[df['street'] == 'Avenida 56 do Estado Rio Grande do Sul']

# %%
estado
# Out:
#    id           created_at first_name last_name email   cell_phone country  \
# 1   1  2017-10-16 00:50:39      Luana   Almeida   NaN  9 7328-8718  Brasil
#
#                state                                  street  number  \
# 1  Rio Grande do Sul  Avenida 56 do Estado Rio Grande do Sul   989.0
#
#    additionals
# 1  Conjunto 17

# %%
#crio a variavel declaro os nomes que precisa
nome=['Almeida', 'Jesus	', 'Teixeira']
#localizar *LOC* isin o nome da variavel
nome = df.loc[df['last_name'].isin(nome)]

# %%
nome
# Out:
#     id           created_at first_name last_name                  email  \
# 1    1  2017-10-16 00:50:39      Luana   Almeida                    NaN
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                    NaN
# 30  30  2018-06-08 07:49:50    Gabriel  Teixeira    gabriel@exemplo.com
# 42  42  2018-04-09 19:12:23       João   Almeida       joão@usuario.com
# 54  54  2018-01-25 02:11:25      Diego  Teixeira      diego@exemplo.com
# 73  73  2018-02-03 07:37:38  Cristiano   Almeida  cristiano@usuario.com
# 74  74  2018-04-22 05:00:28      Júlia   Almeida    júlia@meu_email.com
# 85  85  2017-11-24 12:44:36    Eduardo  Teixeira                    NaN
#
#      cell_phone country                state  \
# 1   9 7328-8718  Brasil    Rio Grande do Sul
# 4   9 3093-6522  Brasil                Bahia
# 30  9 7419-5325  Brasil    Rio Grande do Sul
# 42  9 4650-1753  Brasil                Goiás
# 54  9 5247-1737  Brasil                 Pará
# ...

# %%
df.head(10)
# Out:
#    id           created_at first_name last_name                  email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                    NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                    NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino    daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                    NaN
# 5   5  2018-01-05 17:20:49    Marcelo   Barroso                    NaN
# 6   6  2018-06-18 11:17:42  Cristiano    Elísio  cristiano@exemplo.com
# 7   7  2018-02-08 12:36:09    Everton   Barbosa  everton@meu_email.com
# 8   8  2017-12-16 20:47:03   Gabriela     Alves   gabriela@exemplo.com
# 9   9  2018-11-11 11:48:41       Luan      Dias       luan@exemplo.com
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# ...

# %%
# escolher estados especificos
estados = ['Rio de Janeiro','Ceará', 'Rondônia','Bahia']
Df_estados = df.loc[df['state'].isin(estados)]
Df_estados
# Out:
#     id           created_at first_name    last_name                   email  \
# 4    4  2018-08-06 07:24:16    Romário     Teixeira                     NaN
# 21  21  2018-02-21 15:35:55      Diego       Freire         diego@teste.com
# 24  24  2018-07-25 09:34:12       Jair      Barroso          jair@teste.com
# 32  32  2018-07-22 11:59:27        Ana       Campos           ana@teste.com
# 43  43  2018-01-07 07:54:22    Daniela         Lima                     NaN
# 47  47  2018-09-01 23:00:40      Júlia       Castro       júlia@exemplo.com
# 48  48  2018-05-29 04:22:54   Clarissa  Albuquerque    clarissa@exemplo.com
# 49  49  2018-11-01 02:13:51      Júlia        Sousa       júlia@exemplo.com
# 55  55  2018-07-10 18:40:07   Gabriela        Pires  gabriela@meu_email.com
# 58  58  2018-09-13 03:13:02     Rafael    Rodrigues    rafael@meu_email.com
# 63  63  2018-05-05 17:52:26     Caíque      Batista        caíque@teste.com
# ...

# %%
#Tab e entre = para dar espaço indentar. 
Df_estados2 = df.loc[df['state'].isin(['Rio de Janeiro','Ceará', 'Rondônia','Bahia','Ceará', 'Rondônia','Bahia','Ceará',    
                                       'Rondônia','Bahia','Ceará', 'Rondônia','Bahia','Ceará', 'Rondônia','Bahia','Ceará',  
                                       'Rondônia','Bahia','Ceará', 'Rondônia','Bahia','Ceará', 'Rondônia','Bahia','Ceará',  
                                       'Rondônia','Bahia'])]
Df_estados2
# Out:
#     id           created_at first_name    last_name                   email  \
# 4    4  2018-08-06 07:24:16    Romário     Teixeira                     NaN
# 21  21  2018-02-21 15:35:55      Diego       Freire         diego@teste.com
# 24  24  2018-07-25 09:34:12       Jair      Barroso          jair@teste.com
# 32  32  2018-07-22 11:59:27        Ana       Campos           ana@teste.com
# 43  43  2018-01-07 07:54:22    Daniela         Lima                     NaN
# 47  47  2018-09-01 23:00:40      Júlia       Castro       júlia@exemplo.com
# 48  48  2018-05-29 04:22:54   Clarissa  Albuquerque    clarissa@exemplo.com
# 49  49  2018-11-01 02:13:51      Júlia        Sousa       júlia@exemplo.com
# 55  55  2018-07-10 18:40:07   Gabriela        Pires  gabriela@meu_email.com
# 58  58  2018-09-13 03:13:02     Rafael    Rodrigues    rafael@meu_email.com
# 63  63  2018-05-05 17:52:26     Caíque      Batista        caíque@teste.com
# ...

# %% [markdown]
# #### Tratando Nulos

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_csv\Clientes.csv",delimiter=',')
df.head(5)
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %%
#substrir os valores nulos - NAN
df['Number'] = df ['number'].fillna( 'S/ numuero')
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
#Substituir valores nulos --> NaN
df['street'] =           df['street'].fillna('Nao Cadasatrado')
df['email'] =            df['email'].fillna('Email Não Cadastrado')
df['number'] =           df['number'].fillna('Sem Numero')
df['additionals'] =      df['additionals'].fillna('Sem Info')
df['state'] =           df ['state'].fillna ('Sem estado')

# %%
df.head(30)
# Out:
#     id           created_at first_name    last_name                  email  \
# 0    0  2017-11-01 14:45:41      Marta        Jesus   Email Não Cadastrado
# 1    1  2017-10-16 00:50:39      Luana      Almeida   Email Não Cadastrado
# 2    2  2018-06-16 17:51:29      Frida       Mendes    frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela      Avelino    daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário     Teixeira   Email Não Cadastrado
# 5    5  2018-01-05 17:20:49    Marcelo      Barroso   Email Não Cadastrado
# 6    6  2018-06-18 11:17:42  Cristiano       Elísio  cristiano@exemplo.com
# 7    7  2018-02-08 12:36:09    Everton      Barbosa  everton@meu_email.com
# 8    8  2017-12-16 20:47:03   Gabriela        Alves   gabriela@exemplo.com
# 9    9  2018-11-11 11:48:41       Luan         Dias       luan@exemplo.com
# 10  10  2017-12-16 15:41:00    Mariana        Alves  mariana@meu_email.com
# ...

# %% [markdown]
# #### Metodo Replace

# %%
# Substituindo os nomes dos estados no DataFrame
"""
df['Coluna'] = df['coluna'].replace('valor_original', 'valor_substituto')
"""

# %%
# Resetar DF
df = pd.read_csv(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_csv\Clientes.csv", delimiter=',')
df.head()
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %%
#df['Coluna'] = df['coluna'].replace('valor_original', 'valor_substituto')
#df['country'] = df['country'].replace('Brasil', 'BR')
df['first_name'] = df['first_name'].replace('Luana', 'Carlão')
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39     Carlão   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834      BR               Acre
# ...

# %%
df['state'] = df['state'].replace('São Paulo', 'SP')
df['state'] = df['state'].replace('Acre', 'AC')
df['state'] = df['state'].replace('Distrito Federal', 'DF')

# %%
df.head(20)

# %%
# Resetar DF
df = pd.read_csv(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_csv\Clientes.csv", delimiter=',')
df.head(10)
# Out:
#    id           created_at first_name last_name                  email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                    NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                    NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino    daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                    NaN
# 5   5  2018-01-05 17:20:49    Marcelo   Barroso                    NaN
# 6   6  2018-06-18 11:17:42  Cristiano    Elísio  cristiano@exemplo.com
# 7   7  2018-02-08 12:36:09    Everton   Barbosa  everton@meu_email.com
# 8   8  2017-12-16 20:47:03   Gabriela     Alves   gabriela@exemplo.com
# 9   9  2018-11-11 11:48:41       Luan      Dias       luan@exemplo.com
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# ...

# %%
# Fazendo a substituição de um valor específico com variavel
valor_original = 'São Paulo'
valor_substituto = 'SP'
df['state'] = df['state'].replace(valor_original, valor_substituto)

# %%
df.head(30)
# Out:
#     id           created_at first_name    last_name                  email  \
# 0    0  2017-11-01 14:45:41      Marta        Jesus                    NaN
# 1    1  2017-10-16 00:50:39      Luana      Almeida                    NaN
# 2    2  2018-06-16 17:51:29      Frida       Mendes    frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela      Avelino    daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário     Teixeira                    NaN
# 5    5  2018-01-05 17:20:49    Marcelo      Barroso                    NaN
# 6    6  2018-06-18 11:17:42  Cristiano       Elísio  cristiano@exemplo.com
# 7    7  2018-02-08 12:36:09    Everton      Barbosa  everton@meu_email.com
# 8    8  2017-12-16 20:47:03   Gabriela        Alves   gabriela@exemplo.com
# 9    9  2018-11-11 11:48:41       Luan         Dias       luan@exemplo.com
# 10  10  2017-12-16 15:41:00    Mariana        Alves  mariana@meu_email.com
# ...

# %%
import pandas as pd
# Resetar DF
df = pd.read_csv(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_csv\Clientes.csv", delimiter=',')
df.head()
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %%
# Mapeando os nomes dos estados para substituição
# Obs itens criados entre chves {} significa dicionario - exemplo tirar o acento
mapeamento = {'Maranhão': 'Maranhao', 'Piauí': 'Piaui', 'Goiás': 'Goias','São Paulo':'SPteste'}

# Substituindo os nomes dos estados no DataFrame
df['state'] = df['state'].replace(mapeamento)

# %%
df.head(30)
# Out:
#     id           created_at first_name    last_name                  email  \
# 0    0  2017-11-01 14:45:41      Marta        Jesus                    NaN
# 1    1  2017-10-16 00:50:39      Luana      Almeida                    NaN
# 2    2  2018-06-16 17:51:29      Frida       Mendes    frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela      Avelino    daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário     Teixeira                    NaN
# 5    5  2018-01-05 17:20:49    Marcelo      Barroso                    NaN
# 6    6  2018-06-18 11:17:42  Cristiano       Elísio  cristiano@exemplo.com
# 7    7  2018-02-08 12:36:09    Everton      Barbosa  everton@meu_email.com
# 8    8  2017-12-16 20:47:03   Gabriela        Alves   gabriela@exemplo.com
# 9    9  2018-11-11 11:48:41       Luan         Dias       luan@exemplo.com
# 10  10  2017-12-16 15:41:00    Mariana        Alves  mariana@meu_email.com
# ...
