# %%
import pandas as pd

# %%
# extração padrão
df = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx") 
display(df)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
# extração selecionando guia espesifica (sheet_name + nome da guia excel)
df = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" ,sheet_name='Produto (2)' ) 
display(df)
# Out:
#    Titulo mesclado  Unnamed: 1
# 0               NaN        NaN
# 1               NaN        NaN
# 2              Loja     Vendas
# 3           Niterói        625
# 4          Curitiba        594
# 5    Rio de Janeiro        650
# 6         São Paulo        862
# 7            Cuiabá        452
# 8            Palmas        139
# 9          Teresina        175
# 10           Recife        293
# 11   Santa Catarina        529
# 12           Manaus        507
# 13   Belo Horizonte        705

# %%
# extração selecionando guia espesifica + pula linha (sheet_name + nome da guia excel + skiprows pula quantas linhas quiser )
#skiprows pula linha - que tem os desenhos as cores skiprows=3 quantidade de linhas 
tabelaProduto = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Produto (2)',skiprows=3)
display(tabelaProduto)
# Out:
#               Loja  Vendas
# 0          Niterói     625
# 1         Curitiba     594
# 2   Rio de Janeiro     650
# 3        São Paulo     862
# 4           Cuiabá     452
# 5           Palmas     139
# 6         Teresina     175
# 7           Recife     293
# 8   Santa Catarina     529
# 9           Manaus     507
# 10  Belo Horizonte     705

# %%
# extração selecionando guia espesifica (sheet_name + nome da guia excel)
TabelaProduto = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Vendas')
display(TabelaProduto)
# Out:
#     Vendedor  Vendas  Unnamed: 2  Unnamed: 3  Unnamed: 4            Loja  \
# 0     Lucas      625         NaN         NaN         NaN         Niterói
# 1      Maria     594         NaN         NaN         NaN        Curitiba
# 2    Natália     650         NaN         NaN         NaN  Rio de Janeiro
# 3   Henrique     862         NaN         NaN         NaN       São Paulo
# 4     marcos     452         NaN         NaN         NaN          Cuiabá
# 5      Paula     139         NaN         NaN         NaN          Palmas
# 6    Juliano     175         NaN         NaN         NaN        Teresina
# 7   Gabriela     293         NaN         NaN         NaN          Recife
# 8      Brian     529         NaN         NaN         NaN  Santa Catarina
# 9      Diego     507         NaN         NaN         NaN          Manaus
# 10     kátia     705         NaN         NaN         NaN  Belo Horizonte
#
#     Vendas.1
# 0        625
# 1        594
# 2        650
# 3        862
# 4        452
# ...

# %%
# extração selecionando guia espesifica + pula linha (sheet_name + nome da guia excel + skiprows pula quantas linhas quiser )
#vai puxar a coluna A ate terminar celula
#skiprows pula linha
tabelaProduto = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Vendas',usecols='A:B')
display(tabelaProduto)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
import pandas as pd

# escolhendo coluns espefificas (usecols)
#vai puxar a coluna A ate terminar celula de uma coluna para outra
tabelaProduto = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx", sheet_name='Vendas', usecols='A:B, F:G')

# Display the DataFrame
display(tabelaProduto)
# Out:
#     Vendedor  Vendas            Loja  Vendas.1
# 0     Lucas      625         Niterói       625
# 1      Maria     594        Curitiba       594
# 2    Natália     650  Rio de Janeiro       650
# 3   Henrique     862       São Paulo       862
# 4     marcos     452          Cuiabá       452
# 5      Paula     139          Palmas       139
# 6    Juliano     175        Teresina       175
# 7   Gabriela     293          Recife       293
# 8      Brian     529  Santa Catarina       529
# 9      Diego     507          Manaus       507
# 10     kátia     705  Belo Horizonte       705

# %%
# escolhendo coluns espefificas (usecols)
#vai puxar a coluna A ate terminar celula
produto = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Vendas',usecols='A:B')
display(produto)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
# escolhendo coluns espefificas (usecols  )
Loja = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Vendas',usecols= 'F:G')
display(Loja)
# Out:
#               Loja  Vendas.1
# 0          Niterói       625
# 1         Curitiba       594
# 2   Rio de Janeiro       650
# 3        São Paulo       862
# 4           Cuiabá       452
# 5           Palmas       139
# 6         Teresina       175
# 7           Recife       293
# 8   Santa Catarina       529
# 9           Manaus       507
# 10  Belo Horizonte       705

# %%
# escolhendo coluns espefificas (usecols  )
tabelaProduto2 = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Vendas', usecols=[0,1])
display(tabelaProduto2)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
# escolhendo coluns espefificas (usecols  )
tabelaProduto2 = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Vendas')
display(tabelaProduto2)
# Out:
#     Vendedor  Vendas  Unnamed: 2  Unnamed: 3  Unnamed: 4            Loja  \
# 0     Lucas      625         NaN         NaN         NaN         Niterói
# 1      Maria     594         NaN         NaN         NaN        Curitiba
# 2    Natália     650         NaN         NaN         NaN  Rio de Janeiro
# 3   Henrique     862         NaN         NaN         NaN       São Paulo
# 4     marcos     452         NaN         NaN         NaN          Cuiabá
# 5      Paula     139         NaN         NaN         NaN          Palmas
# 6    Juliano     175         NaN         NaN         NaN        Teresina
# 7   Gabriela     293         NaN         NaN         NaN          Recife
# 8      Brian     529         NaN         NaN         NaN  Santa Catarina
# 9      Diego     507         NaN         NaN         NaN          Manaus
# 10     kátia     705         NaN         NaN         NaN  Belo Horizonte
#
#     Vendas.1
# 0        625
# 1        594
# 2        650
# 3        862
# 4        452
# ...

# %%
# escolhendo coluns espefificas (usecols)  + usando uma lista 
Produto = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Vendas',usecols= [0,1,2])
display(Produto)
# Out:
#     Vendedor  Vendas  Unnamed: 2
# 0     Lucas      625         NaN
# 1      Maria     594         NaN
# 2    Natália     650         NaN
# 3   Henrique     862         NaN
# 4     marcos     452         NaN
# 5      Paula     139         NaN
# 6    Juliano     175         NaN
# 7   Gabriela     293         NaN
# 8      Brian     529         NaN
# 9      Diego     507         NaN
# 10     kátia     705         NaN

# %%
# escolhendo coluns espefificas (usecols)  + usando uma lista pela numeração das colunas
Loja = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Vendas',usecols= [4,5,6])
display(Loja)
# Out:
#     Unnamed: 4            Loja  Vendas.1
# 0          NaN         Niterói       625
# 1          NaN        Curitiba       594
# 2          NaN  Rio de Janeiro       650
# 3          NaN       São Paulo       862
# 4          NaN          Cuiabá       452
# 5          NaN          Palmas       139
# 6          NaN        Teresina       175
# 7          NaN          Recife       293
# 8          NaN  Santa Catarina       529
# 9          NaN          Manaus       507
# 10         NaN  Belo Horizonte       705

# %%
# escolhendo coluns espefificas (usecols)  + usando uma lista pela numeração das colunas
Loja = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Vendas',usecols= [0,1,5,6])
display(Loja)
# Out:
#     Vendedor  Vendas            Loja  Vendas.1
# 0     Lucas      625         Niterói       625
# 1      Maria     594        Curitiba       594
# 2    Natália     650  Rio de Janeiro       650
# 3   Henrique     862       São Paulo       862
# 4     marcos     452          Cuiabá       452
# 5      Paula     139          Palmas       139
# 6    Juliano     175        Teresina       175
# 7   Gabriela     293          Recife       293
# 8      Brian     529  Santa Catarina       529
# 9      Diego     507          Manaus       507
# 10     kátia     705  Belo Horizonte       705

# %%
# escolhendo coluns espefificas    usecols + skiprows
planilha4 = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Planilha4')
display(planilha4)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN         NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN         NaN
# ...

# %%
# escolhendo coluns espefificas    usecols + skiprows tirar as celular de cima para baixo tem 7
planilha4 = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= "Planilha4",usecols="g:h",skiprows=7)
display(planilha4)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
#skiprows = pula linha 
#nrows = seleciona até a quantidade de linhas que voce quiser
LojaProduto = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Planilha5')
display(LojaProduto)
# Out:
#           Vendedor  Vendas
# 0           Lucas      625
# 1            Maria     594
# 2          Natália     650
# 3         Henrique     862
# 4           marcos     452
# 5            Paula     139
# 6          Juliano     175
# 7         Gabriela     293
# 8            Brian     529
# 9            Diego     507
# 10           kátia     705
# 11             NaN     NaN
# 12            Loja  Vendas
# 13         Niterói     625
# 14        Curitiba     594
# 15  Rio de Janeiro     650
# 16       São Paulo     862
# 17          Cuiabá     452
# 18          Palmas     139
# 19        Teresina     175
# 20          Recife     293
# 21  Santa Catarina     529
# 22          Manaus     507
# 23  Belo Horizonte     705

# %%
#skiprows = pula linha 
#nrows = seleciona até a quantidade de linhas que voce quiser tras a quantide linha
produto = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Planilha5' , nrows= 11)
display(produto)
# Out:
#     Vendedor  Vendas
# 0     Lucas      625
# 1      Maria     594
# 2    Natália     650
# 3   Henrique     862
# 4     marcos     452
# 5      Paula     139
# 6    Juliano     175
# 7   Gabriela     293
# 8      Brian     529
# 9      Diego     507
# 10     kátia     705

# %%
#skiprows = pula linha 
#nrows = seleciona até a quantidade de linhas que voce quiser 
Loja = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Planilha5' , skiprows= 13)
display(Loja)
# Out:
#               Loja  Vendas
# 0          Niterói     625
# 1         Curitiba     594
# 2   Rio de Janeiro     650
# 3        São Paulo     862
# 4           Cuiabá     452
# 5           Palmas     139
# 6         Teresina     175
# 7           Recife     293
# 8   Santa Catarina     529
# 9           Manaus     507
# 10  Belo Horizonte     705

# %%
#pular linhas skiprows
Loja = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Planilha5' ,usecols='F:G', skiprows=14)
display(Loja)
# Out:
#               Loja  Vendas
# 0          Niterói     625
# 1         Curitiba     594
# 2   Rio de Janeiro     650
# 3        São Paulo     862
# 4           Cuiabá     452
# 5           Palmas     139
# 6         Teresina     175
# 7           Recife     293
# 8   Santa Catarina     529
# 9           Manaus     507
# 10  Belo Horizonte     705

# %%
Loja = pd.read_excel(r"C:\Users\Leticia\Desktop\Python-Banco de Dados\Banco de dados\Origem\arquivos_excel\Caquinha.xlsx" , sheet_name= 'Planilha5' ,usecols='F:G', nrows=12)
display(Loja)
# Out:
#    Unnamed: 5 Unnamed: 6
# 0    Vendedor     Vendas
# 1      Lucas         625
# 2       Maria        594
# 3     Natália        650
# 4    Henrique        862
# 5      marcos        452
# 6       Paula        139
# 7     Juliano        175
# 8    Gabriela        293
# 9       Brian        529
# 10      Diego        507
# 11      kátia        705
